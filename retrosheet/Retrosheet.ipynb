# %%
import subprocess
import pandas

# %%
path = '/Users/youngty/Projects/baseball_data/retrosheet/2017/2017ANA.csv'
with open(path, "a") as file:
    file.flush()
    #print(subprocess.call(['cwevent','-d','-y', '2017', '2017ANA.EVA'],cwd='2017'))
    subprocess.call(['cwevent','-f', '0-96','-y', '2017', '-a' , '2017ANA.EVA'],cwd='2017', stdout=file)
df = pandas.read_csv('/Users/youngty/Projects/baseball_data/retrosheet/2017/2017ANA.csv')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6229 entries, 0 to 6228
# Data columns (total 97 columns):
# ANA201704070    6229 non-null object
# SEA             6229 non-null object
# 1               6229 non-null int64
# 0               6229 non-null int64
# 0.1             6229 non-null int64
# 3               6229 non-null int64
# 2               6229 non-null int64
# CBSBBB          6229 non-null object
# 0.2             6229 non-null int64
# 0.3             6229 non-null int64
# seguj002        6229 non-null object
# R               6229 non-null object
# seguj002.1      6229 non-null object
# R.1             6229 non-null object
# chavj001        6229 non-null object
# R.2             6229 non-null object
# chavj001.1      6229 non-null object
# R.3             6229 non-null object
# maldm001        6229 non-null object
# cronc002        6229 non-null object
# espid001        6229 non-null object
# escoy001        6229 non-null object
# ...
